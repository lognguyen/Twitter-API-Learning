# %%
import json

name = 'stream_PL.json'
with open(name,'r') as f:
    line = f.readline()
    tweet = json.loads(line)
    print(json.dumps(tweet,indent=4))

f.close()
# Out:
# {
#     "created_at": "Fri Sep 04 03:37:56 +0000 2020",
#     "id": 1301726160779382785,
#     "id_str": "1301726160779382785",
#     "text": "RT @camilarz_: xq se me hace tan dif\u00edcil sacar pl\u00e1tica? me odio",
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "truncated": false,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#         "id": 1128902453729083393,
#         "id_str": "1128902453729083393",
#         "name": "blossom",
#         "screen_name": "reginaquirozz",
#         "location": null,
#         "url": "http://vsco.co/reginaquirozz",
#         "description": "e i g h t e e n",
#         "translator_type": "none",
#         "protected": false,
#         "verified": false,
#         "followers_count": 340,
#         "friends_count": 363,
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
import json
with open('stream_PL.json','r') as f:
    for line in f:
        try:
            tweet = json.loads(line)
            tokens = preprocess(tweet['text'])
            print(tokens)
        except ValueError:
            print("Decoding Failed")
        

f.close()
# Out:
# ['RT', '@camilarz_', ':', 'xq', 'se', 'me', 'hace', 'tan', 'dif', 'ícil', 'sacar', 'plática', '?', 'me', 'odio']
# Decoding Failed
# ['RT', '@KODAKUMINET', ':', 'Apple', 'Music', 'の', '「', 'ニュー', '・', 'ミュージック', '・', 'デイリー', '」', 'に新曲', '「', 'XXKK', '」', 'が選曲されました', '🙏', '😆', '是非Apple', 'Music', 'でチェックしてください', '！', 'https://t.co/4rBqibd2tA', '@AppleMusicJapan', '#', '倖', '…']
# Decoding Failed
# ['RT', '@hei_ne52', ':', '@HolgerEwald1', '@Fantareis', 'Die', 'Amerikaner', ',', 'die', 'Russen', ',', 'jetzt', 'noch', 'die', 'Schweden', '.', 'Wer', 'noch', '?', 'Alle', 'sollen', 'die', 'Deutschen', 'retten', '.', 'War', '…']
# Decoding Failed
# ['RT', '@riiizi', ':', 'A', 'capa', 'é', 'de', '@VitoQuintans', 'que', 'ficou', 'incr', 'ível', 'como', 'ele', '😊']
# Decoding Failed
# ...

# %%
from nltk.corpus import stopwords
from nltk import bigrams
import string
import operator
import json
from collections import Counter

punctuation = list(string.punctuation)
# rt = retweet 
stop = stopwords.words('english') + punctuation + ['RT','via']

# 10 most common chars
with open(name,'r') as f:
    count_all = Counter()
    for line in f:
        try:  
            tweet = json.loads(line)
            terms_list = [term for term in preprocess(tweet['text']) if term not in stop]
            count_all.update(terms_list)
        except ValueError:
            continue
    print(count_all.most_common(10))
# Out:
# [('、', 260), ('・', 215), ('…', 188), ('。', 123), ('『', 117), ('！', 95), ('』', 89), ('de', 58), ('ボイス実装', 58), ('キャンペーンにご参加いただき', 58)]

# %%
from nltk.corpus import stopwords
from nltk import bigrams
import string

punctuation = list(string.punctuation)
# rt = retweet 
stop = stopwords.words('english') + punctuation + ['RT','via']

with open(name,'r') as f:
    count_all = Counter()
    for line in f:
        try:  
            tweet = json.loads(line)
            terms_stop = [term for term in preprocess(tweet['text']) if term not in stop]
            term_bigram = bigrams(terms_stop)
            count_all.update(term_bigram)
        except ValueError:
            continue
    print(count_all.most_common(10))


f.close()
# Out:
# [(('・', '・'), 116), (('『', 'ボイス実装'), 58), (('ボイス実装', '』'), 58), (('』', 'キャンペーンにご参加いただき'), 58), (('キャンペーンにご参加いただき', '、'), 58), (('、', 'ありがとうございます'), 58), (('ありがとうございます', '。'), 58), (('。', '抽選の結果'), 58), (('抽選の結果', '、'), 58), (('、', '外れてしまいました'), 58)]
