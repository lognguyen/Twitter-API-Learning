# %%
import nltk
import tweepy
import json
from tweepy import OAuthHandler

## Confidential info ##
consumer_key =''
consumer_secret =''
access_token = ''
access_secret = ''
## Confidential info ##

auth = OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)

api= tweepy.API(auth)

def process_or_store(tweet):
    print(json.dumps(tweet))

# %%
#streaming API to get up-to-date data
# from tweepy import Stream
# from tweepy.streaming import StreamListener


# class MyListener(StreamListener):
 
#     def on_data(self, data):
#         try:
#             with open('python.json', 'a') as f:
#                 f.write(data)
#                 return True
#         except BaseException as e:
#             print("Error on_data: %s" % str(e))
#         return True
 
#     def on_error(self, status):
#         print(status)
#         return True
 
# twitter_stream = Stream(auth, MyListener())
# twitter_stream.filter(track=['#PL'])

# %%
#timeline reading (Twitter homepage) ~ so we don't have to open twitter 
#15 tweets
for status in tweepy.Cursor(api.home_timeline).items(15):
    print(status.text)
# Out:
# 🎧 Sσυɳԃ Oɳ 🎧 https://t.co/K5gfocD4jF
# ✅ Youngest player in Barça history to score in @LaLigaEN
#
# ✅ Youngest player in history to score in the… https://t.co/lXIre3aeow
# If you bombard Earth with enough photons, eventually it emits a Tesla (AK)
# #EURO21KitsShowdown: Round of 16 👕
# Austria vs. Netherlands 🇦🇹🇳🇱
# Haaland dropped the Michu celebration for Norway tonight.
#
# A tribute to his childhood idol. 💥 https://t.co/nupPPkn6rF
# First-time top bins 😎
#
# #GoalOfTheDay https://t.co/VdNF7fisYJ
# Roma confirmed Nicolo Zaniolo injured his left knee during Italy's game vs. Netherlands and will undergo tests on T… https://t.co/lu8KVlgwnz
# 🇺🇸 Happy Labor Day from Barcelona. @konradjr https://t.co/WHn3DGutdO
# ⚽️⚽️ https://t.co/Zd9QEBFzRI
# #EURO21KitsShowdown: Round of 16 👕
# Germany vs. Russia 🇩🇪🇷🇺
# —Sporting
# —Barcelona
# —Porto
# —Inter Milan
# —Chelsea
# —Besiktas
# —Al-Ahli
# —Porto
# —Besiktas
# —Kasimpasa
#
# Ricardo Quaresma… https://t.co/YT2p9Y5TH9
# ...

# %%
for status in tweepy.Cursor(api.home_timeline).items(15):
    process_or_store(status._json)
# Out:
# {"created_at": "Tue Sep 08 01:31:32 +0000 2020", "id": 1303143902132744193, "id_str": "1303143902132744193", "text": "\ud83c\udfa7 S\u03c3\u03c5\u0273\u0503 O\u0273 \ud83c\udfa7 https://t.co/K5gfocD4jF", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [], "media": [{"id": 1303143729453305856, "id_str": "1303143729453305856", "indices": [13, 36], "media_url": "http://pbs.twimg.com/media/EhWyYMUWAAUNv28.jpg", "media_url_https": "https://pbs.twimg.com/media/EhWyYMUWAAUNv28.jpg", "url": "https://t.co/K5gfocD4jF", "display_url": "pic.twitter.com/K5gfocD4jF", "expanded_url": "https://twitter.com/FCBarcelona/status/1303143902132744193/video/1", "type": "photo", "sizes": {"thumb": {"w": 150, "h": 150, "resize": "crop"}, "medium": {"w": 1200, "h": 675, "resize": "fit"}, "small": {"w": 680, "h": 383, "resize": "fit"}, "large": {"w": 1280, "h": 720, "resize": "fit"}}}]}, "extended_entities": {"media": [{"id": 1303143729453305856, "id_str": "130314372
# ...

# %%
for friend in tweepy.Cursor(api.friends,name="Donny van de Beek").items():
    process_or_store(friend._json)
# Out:
# {"id": 1699890626, "id_str": "1699890626", "name": "Donny van de Beek", "screen_name": "Donny_beek6", "location": "", "description": "Player of Manchester United", "url": "https://t.co/jiAigGC9rO", "entities": {"url": {"urls": [{"url": "https://t.co/jiAigGC9rO", "expanded_url": "http://playersunited.com", "display_url": "playersunited.com", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 239673, "friends_count": 161, "listed_count": 315, "created_at": "Sun Aug 25 18:45:41 +0000 2013", "favourites_count": 31, "utc_offset": null, "time_zone": null, "geo_enabled": true, "verified": true, "statuses_count": 388, "lang": null, "status": {"created_at": "Thu Sep 03 07:28:19 +0000 2020", "id": 1301421749750374401, "id_str": "1301421749750374401", "text": "Very excited to be the newest edition of the #MUFC family. \ud83d\udd34 Your enthusiastic responses to my announcement make me\u2026 https://t.co/1R46VLAlV9", "truncated": true, "entities": {"hasht
# ...

# %%
for tweet in tweepy.Cursor(api.user_timeline).items():
    process_or_store(tweet._json)

# %%
import json
import requests

# response = requests.get("https://jsonplaceholder.typicode.com/todos")
# todos = json.loads(response.text)

# todos[10]
# for friend in tweepy.Cursor(api.friends).items():
#     data = json.loads(friends._json)
    
    
    
# count = 0
# for todo in todos:
#     if (todo['userId'] == 2) & (todo['id'] == 21):
#         print(todo)

# %%
## Confidential info ##
consumer_key =''
consumer_secret =''
access_token = ''
access_secret = ''
## Confidential info ##

def get_tweepy_api(consumer_key='', consumer_secret='', access_token_key='', access_token_secret='', wait_on_rate_limit=False):
    if not(all((consumer_key, consumer_secret, access_token_key, access_token_secret,))):
        (consumer_key, consumer_secret, access_token_key, access_token_secret,) = _get_auth_keys()
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token_key, access_token_secret)
    return api

def get_user(screen_name):
    api = get_tweepy_api()
    twitter_user = api.get_user(screen_name=screen_name)
    return twitter_user

print(get_user("Donny_beek6"))
# Out:
# User(_api=<tweepy.api.API object at 0x00000234FCC53D68>, _json={'id': 1699890626, 'id_str': '1699890626', 'name': 'Donny van de Beek', 'screen_name': 'Donny_beek6', 'location': '', 'profile_location': None, 'description': 'Player of Manchester United', 'url': 'https://t.co/jiAigGC9rO', 'entities': {'url': {'urls': [{'url': 'https://t.co/jiAigGC9rO', 'expanded_url': 'http://playersunited.com', 'display_url': 'playersunited.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 239639, 'friends_count': 161, 'listed_count': 315, 'created_at': 'Sun Aug 25 18:45:41 +0000 2013', 'favourites_count': 31, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 388, 'lang': None, 'status': {'created_at': 'Thu Sep 03 07:28:19 +0000 2020', 'id': 1301421749750374401, 'id_str': '1301421749750374401', 'text': 'Very excited to be the newest edition of the #MUFC family. 🔴 Your enthusiastic responses to my announcement 
# ...

# %%
from nltk.tokenize import sent_tokenize
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""
tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %%
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 25 samples and 30 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('is', 3), (',', 2)]

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show();

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {"haven't", 'having', 'too', 'can', 'on', 'then', 'do', 'weren', 'up', 'or', 'haven', 'herself', 'mustn', 'most', 'before', 'your', "hasn't", 'doing', 'by', 'being', "wasn't", 'again', 'have', 'during', 'i', 'once', 'if', "needn't", 'mightn', 'had', "you've", 'through', 'does', 'against', 't', 'himself', "isn't", 'be', 'when', 'myself', 'aren', 'until', 'into', 'me', 'above', 'from', 'other', "won't", 've', 'and', 'who', 'some', 'we', 'is', 'couldn', 'he', 'shan', "shouldn't", 'not', 'an', 'been', "she's", 'after', 'each', 'here', 'doesn', 'yourself', 'for', 'isn', 'yourselves', 'this', 'where', 'just', 're', 's', 'll', "weren't", 'how', 'further', 'in', 'a', 'there', 'will', 'was', 'down', 'hasn', "don't", 'that', 'd', 'ma', 'ain', "that'll", 'these', 'the', 'were', "mustn't", 'few', 'she', "shan't", 'very', 'wasn', 'all', "didn't", 'why', 'm', 'than', 'own', 'shouldn', 'whom', 'did', 'out', "wouldn't", 'my', 'him', 'them', 'needn', 'ours', 'of', 'but', 'at', 'only', 'won', "doesn't
# ...
